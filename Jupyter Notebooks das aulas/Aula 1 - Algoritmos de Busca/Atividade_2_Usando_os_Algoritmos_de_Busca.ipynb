# %% [markdown]
# # Enunciado
#
# Utilizando os algoritmos de busca das aulas (Busca Gulosa e Busca A*) execute a busca com o cenário abaixo.
#
#
# Vide recursos abaixo:

# %% [markdown]
# Cidade de origem: **Porto União**
#
# Cidade de Destino: **Curitiba**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Implemente a solução abaixo...

# %% [markdown]
# ## Busca Gulosa:

# %% [markdown]
# ## Busca A*:
